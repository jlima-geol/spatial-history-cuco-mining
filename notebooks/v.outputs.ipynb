# %% [markdown]
# # Spatial Copper Mining in DR Congo - Outputs

# %% [markdown]
# ## 5. Outputs
#
# - Maps
# - Time‑series charts
# - Spatial narratives
# - Environmental indicators
# - Visualizations
