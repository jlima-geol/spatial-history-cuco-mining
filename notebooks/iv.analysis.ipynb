# %% [markdown]
# # Spatial Copper Mining in DR Congo - Analysis

# %% [markdown]
# ## 4. Analysis
#
# - Change detection
# - Environmental degradation
# - Infrastructure–mining relationships
# - Spatial clustering of mines
# - Time‑series analysis
